# %% [markdown]
# ## Line chart

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
x = np.linspace(0, 20, 1000)
x.shape
# Out:
# (1000,)

# %%
y = np.sin(x) + .2 * x

y.shape
# Out:
# (1000,)

# %%
plt.plot(x, y)

plt.show() # No need it i fin Jupyter env

# %%
plt.plot(x, y)

plt.xlabel('Input')
plt.xlabel('Output')
plt.title('My Plot'); # Semicolon makes class notation disapear
# Out:
# Text(0.5, 1.0, 'My Plot')
